# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
# %matplotlib inline

# %%
df=pd.read_csv("AEP_hourly.csv")
df
# Out:
#                    Datetime   AEP_MW
# 0       2004-12-31 01:00:00  13478.0
# 1       2004-12-31 02:00:00  12865.0
# 2       2004-12-31 03:00:00  12577.0
# 3       2004-12-31 04:00:00  12517.0
# 4       2004-12-31 05:00:00  12670.0
# ...                     ...      ...
# 121268  2018-01-01 20:00:00  21089.0
# 121269  2018-01-01 21:00:00  20999.0
# 121270  2018-01-01 22:00:00  20820.0
# 121271  2018-01-01 23:00:00  20415.0
# 121272  2018-01-02 00:00:00  19993.0
#
# [121273 rows x 2 columns]

# %%
df.describe()
# Out:
#               AEP_MW
# count  121273.000000
# mean    15499.513717
# std      2591.399065
# min      9581.000000
# 25%     13630.000000
# 50%     15310.000000
# 75%     17200.000000
# max     25695.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Datetime    0
# AEP_MW      0
# dtype: int64

# %%
dataset=df
dataset["Month"]=pd.to_datetime(df["Datetime"]).dt.month
dataset["Year"]=pd.to_datetime(df["Datetime"]).dt.year
dataset["Date"]=pd.to_datetime(df["Datetime"]).dt.date
dataset["Time"]=pd.to_datetime(df["Datetime"]).dt.time
# dataset["Week"]=pd.to_datetime(df["Datetime"]).dt.week
dataset["Day"]=pd.to_datetime(df["Datetime"]).dt.day_name()
dataset=df.set_index("Datetime")
dataset.index=pd.to_datetime(dataset.index)
dataset
# Out:
#                       AEP_MW  Month  Year        Date      Time      Day
# Datetime
# 2004-12-31 01:00:00  13478.0     12  2004  2004-12-31  01:00:00   Friday
# 2004-12-31 02:00:00  12865.0     12  2004  2004-12-31  02:00:00   Friday
# 2004-12-31 03:00:00  12577.0     12  2004  2004-12-31  03:00:00   Friday
# 2004-12-31 04:00:00  12517.0     12  2004  2004-12-31  04:00:00   Friday
# 2004-12-31 05:00:00  12670.0     12  2004  2004-12-31  05:00:00   Friday
# ...                      ...    ...   ...         ...       ...      ...
# 2018-01-01 20:00:00  21089.0      1  2018  2018-01-01  20:00:00   Monday
# 2018-01-01 21:00:00  20999.0      1  2018  2018-01-01  21:00:00   Monday
# 2018-01-01 22:00:00  20820.0      1  2018  2018-01-01  22:00:00   Monday
# 2018-01-01 23:00:00  20415.0      1  2018  2018-01-01  23:00:00   Monday
# 2018-01-02 00:00:00  19993.0      1  2018  2018-01-02  00:00:00  Tuesday
#
# [121273 rows x 6 columns]

# %%
print(df.Year.unique())
print("total number of unique year",df.Year.nunique())
# Out:
# [2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018]
# total number of unique year 15

# %%
#energy consupmtion each year
from matplotlib import style

style.use('ggplot')
sns.lineplot(x=dataset["Year"],y=dataset["AEP_MW"])

plt.title("Energy consumption according to year")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'dataset' is already loaded

# Create the figure and axis
fig, ax1 = plt.subplots()

# Plotting data for 2004
y_2004 = dataset[dataset['Year'] == 2004]['AEP_MW'].to_list()  # Get the AEP_MW for 2004
x_2004 = dataset[dataset['Year'] == 2004]['Date'].to_list()  # Get the Date for 2004 (adjust column name if needed)
ax1.plot(x_2004, y_2004, color="green", linewidth=1.7)

# Plotting data for 2005
y_2005 = dataset[dataset['Year'] == 2005]['AEP_MW'].to_list()
x_2005 = dataset[dataset['Year'] == 2005]['Date'].to_list()
ax1.plot(x_2005, y_2005, color="blue", linewidth=1)

# Plotting data for 2006
y_2006 = dataset[dataset['Year'] == 2006]['AEP_MW'].to_list()
x_2006 = dataset[dataset['Year'] == 2006]['Date'].to_list()
ax1.plot(x_2006, y_2006, color="red", linewidth=1)

# Customize plot appearance
plt.rcParams["figure.figsize"] = (18, 8)
plt.title("Energy Consumption Over Years")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True, alpha=1)
plt.legend(["2004", "2005", "2006"])

# Rotate x-axis labels for better readability
for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)

# Adjust layout to prevent label overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.distplot(dataset["AEP_MW"])
plt.title("energy distribution")
plt.show()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_23832\2351425025.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["AEP_MW"])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 121273 entries, 2004-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   AEP_MW  121273 non-null  float64
#  1   Month   121273 non-null  int32
#  2   Year    121273 non-null  int32
#  3   Date    121273 non-null  object
#  4   Time    121273 non-null  object
#  5   Day     121273 non-null  object
# dtypes: float64(1), int32(2), object(3)
# memory usage: 5.6+ MB

# %%
dataset['Time'] = pd.to_datetime(dataset['Time'], format='%H:%M:%S', errors='coerce')
dataset['Time'] = dataset['Time'].dt.hour
print(dataset['Time'].head())
# Out:
# Datetime
# 2004-12-31 01:00:00    1
# 2004-12-31 02:00:00    2
# 2004-12-31 03:00:00    3
# 2004-12-31 04:00:00    4
# 2004-12-31 05:00:00    5
# Name: Time, dtype: int32

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(111)

sns.lineplot(x="Time", y="AEP_MW", data=dataset)  # Use dataset (not df)
plt.title("Energy consumption vs time")
plt.xlabel("Time")
plt.grid(True, alpha=1)
plt.legend(["AEP_MW"])  # Add a manual legend if needed

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
plt.show()

# %%
# Ensure the index is a datetime type for resampling,resampling 1 value for a day
dataset.index = pd.to_datetime(dataset.index)
numeric_dataset = dataset.select_dtypes(include=['float64', 'int64', 'int32'])
NewDataSet = numeric_dataset.resample('D').mean()
print("new dataset",NewDataSet)
print("old dataset",dataset)
# Out:
# new dataset                   AEP_MW  Month    Year  Time
# Datetime
# 2004-10-01  14284.521739   10.0  2004.0  12.0
# 2004-10-02  12999.875000   10.0  2004.0  11.5
# 2004-10-03  12227.083333   10.0  2004.0  11.5
# 2004-10-04  14309.041667   10.0  2004.0  11.5
# 2004-10-05  14439.708333   10.0  2004.0  11.5
# ...                  ...    ...     ...   ...
# 2018-07-30  15368.083333    7.0  2018.0  11.5
# 2018-07-31  15180.291667    7.0  2018.0  11.5
# 2018-08-01  15151.166667    8.0  2018.0  11.5
# 2018-08-02  15687.666667    8.0  2018.0  11.5
# 2018-08-03  14809.000000    8.0  2018.0   0.0
#
# [5055 rows x 4 columns]
# old dataset                       AEP_MW  Month  Year        Date  Time      Day
# Datetime
# 2004-12-31 01:00:00  13478.0     12  2004  2004-12-31     1   Friday
# 2004-12-31 02:00:00  12865.0     12  2004  2004-12-31     2   Friday
# 2004-12-31 03:00:00  12577.0     12  2004  2004-12-31     3   Friday
# ...

# %%
TestData=NewDataSet.tail(100)
Training_Set=NewDataSet.iloc[:,0:1]
Training_Set=Training_Set[:-60]

# %%
print("training set shape",Training_Set.shape)
print("testing set shape",TestData.shape)
# Out:
# training set shape (4995, 1)
# testing set shape (100, 4)

# %%
X_Train=[]

Y_Train=[]

for i in range(60,Train.shape[0]):
	X_Train.append(Train[i-60:i])
	Y_Train.append(Train[i])

X_Train=np.array(X_Train)
Y_Train=np.array(Y_Train)

print(X_Train.shape)
print(Y_Train.shape)
# Out:
# (4935, 60, 1)
# (4935, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))

# Use fit_transform correctly
Train = sc.fit_transform(Training_Set)

# %%
regressor=Sequential()
regressor.add(LSTM(units=50,return_sequences=True,input_shape=(X_Train.shape=(X_Train.shape[1],1))))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50,return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))


regressor.add(Dense(units=1))

regressor.compile(optimizer='adam',loss='mean_squared_error')
# Out:
#   Cell In[168], line 2
#     regressor.add(LSTM(units=50,return_sequences=True,input_shape=(X_Train.shape=(X_Train.shape[1],1))))
#                                                                    ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

regressor = Sequential()

# Corrected line: Use the correct input_shape format
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_Train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units=1))

# Compile the model
regressor.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# C:\Users\priya\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
regressor.fit(X_Train,Y_Train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - loss: 0.0045
# Epoch 2/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - loss: 0.0045
# Epoch 3/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 0.0045
# Epoch 4/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 0.0043
# Epoch 5/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 0.0042
# Epoch 6/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 0.0046
# Epoch 7/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 0.0041
# Epoch 8/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - loss: 0.0042
# Epoch 9/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 0.0042
# Epoch 10/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - loss: 0.0043
# Epoch 11/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 0.0045
# Epoch 12/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 0.0045
# Epoch 13/50
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - loss: 0.0039
# Epoch 14/50
# ...

# %%
TestData.head(2)
# Out:
#                   AEP_MW  Month    Year  Time
# Datetime
# 2018-04-26  13157.791667    4.0  2018.0  11.5
# 2018-04-27  12964.000000    4.0  2018.0  11.5

# %%
TestData.shape
# Out:
# (100, 4)

# %%
NewDataSet.shape
# Out:
# (5055, 4)

# %%
Df_Total=pd.concat((NewDataSet[["AEP_MW"]],TestData[["AEP_MW"]]),axis=0)

# %%
Df_Total.shape
# Out:
# (5155, 1)

# %%
inputs=Df_Total[len(Df_Total)-len(TestData)-60:].values

inputs.shape
# Out:
# (160, 1)

# %%
inputs=Df_Total[len(Df_Total)-len(TestData)-60:].values

inputs=inputs.reshape(-1,1)

inputs=sc.transform(inputs)

X_test=[]
for i in range(60,160):
	X_test.append(inputs[i-60:i])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],
X_test.shape[1],1))

predicted_stock_price=regressor.predict(X_test)

predicted_stock_price=sc.inverse_transform(predicted_stock_price)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\priya\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
True_MegaWatt=TestData["AEP_MW"].to_list()
Predicted_MegaWatt=predicted_stock_price
dates=TestData.index.to_list()

# %%
Machine_Df=pd.DataFrame(data={
"Date":dates,
"TrueMegaWatt":True_MegaWatt,
"PredictedMegaWatt":[x[0] for x in Predicted_MegaWatt]
})

# %%
#future predictions

# %%
Machine_Df
# Out:
#          Date  TrueMegaWatt  PredictedMegaWatt
# 0  2018-04-26  13157.791667       13534.529297
# 1  2018-04-27  12964.000000       12648.712891
# 2  2018-04-28  12237.583333       14454.834961
# 3  2018-04-29  12156.791667       13376.035156
# 4  2018-04-30  13443.500000       12810.660156
# ..        ...           ...                ...
# 95 2018-07-30  15368.083333       15061.874023
# 96 2018-07-31  15180.291667       15535.585938
# 97 2018-08-01  15151.166667       15113.080078
# 98 2018-08-02  15687.666667       15494.966797
# 99 2018-08-03  14809.000000       15623.086914
#
# [100 rows x 3 columns]

# %%
True_MegaWatt=TestData["AEP_MW"].to_list()
Predicted_MegaWatt=[x[0] for x in Predicted_MegaWatt]
dates=TestData.index.to_list()

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)

x=dates
y=True_MegaWatt

y1=Predicted_MegaWatt
#red line predicted by machine learning 
plt.plot(x,y,color="green")
plt.plot(x,y1,color="red")
plt.xlabel("Dates")
plt.ylabel("power in MW")
plt.title("machine learned the pattern predicting future values")
plt.legend()
plt.show()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_23832\1246637702.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
